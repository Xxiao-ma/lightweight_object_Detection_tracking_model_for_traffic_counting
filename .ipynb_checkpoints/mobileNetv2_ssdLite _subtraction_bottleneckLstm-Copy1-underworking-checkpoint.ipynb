# %%
#set seed
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(1)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

import re
from keras.optimizers import Adam,SGD,RMSprop
from keras import backend as K
import numpy as np
'''
if('tensorflow' == K.backend()):
    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
'''
from math import ceil
#network
#This one is return_sequences=True in LSTM
#from models.keras_mobilenet_v2_ssdlite_lstm_drop19and1fm_6_TimeDisPredictBlock import mobilenet_v2_ssd

# This one is return_sequences=False in LSTM
from models.test_Bottleneck_rnn_net import mobilenet_v2_ssd
#from models.keras_mobilenet_v2_ssdlite_lstm_drop19and1fm_6_dropTdForBNandConcat import mobilenet_v2_ssd
from losses.keras_ssd_loss import SSDLoss
from data_generatorNowInUse.object_detection_2d_data_generator_lstm_origin import DataGenerator

#from data_generatorNowInUse.object_detection_2d_data_generator_lstm import DataGenerator
from data_generatorNowInUse.object_detection_2d_geometric_ops import Resize
from data_generatorNowInUse.object_detection_2d_photometric_ops import ConvertTo3Channels
from utils.data_augmentation_chain_original_ssd import SSDDataAugmentation
from utils.coco import get_coco_category_maps
from utils.ssd_input_encoder import SSDInputEncoder
from keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
from matplotlib import pyplot as plt
from ssd_encoder_decoder.ssd_output_decoder import decode_detections, decode_detections_fast
#from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms

# %matplotlib inline
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-b575ec017a46> in <module>
#      21
#      22 # This one is return_sequences=False in LSTM
# ---> 23 from models.keras_mobilenet_v2_ssdlite_lstm_drop19and1fm_6_TimeDisPredictBlock import mobilenet_v2_ssd
#      24 #from models.keras_mobilenet_v2_ssdlite_lstm_drop19and1fm_6_dropTdForBNandConcat import mobilenet_v2_ssd
#      25 from losses.keras_ssd_loss import SSDLoss
#
# ~/ssdkeras/project_in_git/MobileNetv2_SSDlite/models/keras_mobilenet_v2_ssdlite_lstm_drop19and1fm_6_TimeDisPredictBlock.py in <module>
#       9 from layers.DecodeDetectionsLayer import DecodeDetections
#      10 from layers.DecodeDetectionsFastLayer import DecodeDetectionsFast
# ---> 11 from models.graphs.test_Bottleneck_rnn_net import mobilenet_v2_ssdlite #this is the backbone with bottelneck Lstm
#      12
#      13 # below is origin
#
# ModuleNotFoundError: No module named 'models.graphs.test_Bottleneck_rnn_net'

# %%
#SSD configuation

img_height = 300 # Height of the model input images
img_width = 300 # Width of the model input images
img_channels = 3 # Number of color channels of the model input images
timesteps = 1 # Time step for sequence input frames
#mean_color = [123, 117, 104] # The per-channel mean of the images in the dataset. Do not change this value if you're using any of the pre-trained weights.
#swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
n_classes = 7 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO

#??what decide the anchor box scaling factor??
#scale，对于每个featuremap 它的anchor的计算 Sk = Smin +[(Smax - Smin)/(m-1)]*(k-1)
#其中Smin默认是0.2,表示最低层的scale为0.2,默认Smax 为0.9,同时也拥有长宽比alpha，所以能求得每个anchor的宽Sk*sqr(alpha)和高Sk/sqr(alpha)
#默认 m=6 ， scale:[0.2,0.34,0.48,0.62,0.76,0.9]
#结果乘以图片实际款高即可得到anchor的实际大小
scales_pascal = [0.2, 0.37, 0.54, 0.71, 0.88] # min 0.1 max 1.05 The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
 # min 0.1 max 1.05 The anchor box scaling factors used in the original SSD300 for the Pascal VOC datasets
scales_coco = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # The anchor box scaling factors used in the original SSD300 for the MS COCO datasets
scales = scales_pascal
#长宽比# 6 6 6 4 
aspect_ratios = [[1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5, 3.0, 1.0/3.0],
                 [1.0, 2.0, 0.5]] # The anchor box aspect ratios used in the original SSD300; the order matters

two_boxes_for_ar1 = True
steps = [16, 32, 64, 100] # 特征图cell的大小The space between two adjacent anchor box center points for each predictor layer.
offsets = [ 0.5, 0.5, 0.5, 0.5] # 偏移值，用来确定先验框中心The offsets of the first anchor box center points from the top and left borders of the image as a fraction of the step size for each predictor layer.
clip_boxes = False # Whether or not to clip the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are divided as in the original implementation
normalize_coords = True

# %%
sequence_size=1 #actually batch size
batch_size=1 #actually seq size == timesteps

# %%
#Build the model
K.clear_session()

model = mobilenet_v2_ssd(image_size=(img_height, img_width, img_channels),
                n_classes=n_classes,
                mode='training',
                l2_regularization=0.0005,
                scales=scales,
                aspect_ratios_per_layer=aspect_ratios,
                two_boxes_for_ar1=two_boxes_for_ar1,
                steps=steps,
                offsets=offsets,
                clip_boxes=clip_boxes,
                variances=variances,
                normalize_coords=normalize_coords,
                batch_size=batch_size,
                sequence_size=sequence_size)
# train from scratch.0, 2.0, 0.5, 3.0, 1.0/3.0],h, no weights to load
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0, clipvalue=0.5)
opt = SGD(lr=0.001, momentum=0.9, clipvalue=0.5)
rms = RMSprop(lr=0.003)
ssd_loss = SSDLoss(neg_pos_ratio=10, alpha=1.0)
# set_trainable(r"(ssd\_[cls|box].*)", model)
model.compile(optimizer=rms, loss=ssd_loss.compute_loss)

print(model.summary())
#Total params: 3,160,240
#Trainable params: 3,108,888
# Out:
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# changed scale
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/ssdkeras/project_in_git/MobileNetv2_SSDlite/losses/keras_ssd_loss.py:87: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/ssdkeras/project_in_git/MobileNetv2_SSDlite/losses/keras_ssd_loss.py:129: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /home/xiaoxiao/ssdkeras/project_in_git/MobileNetv2_SSDlite/losses/keras_ssd_loss.py:68: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/xiaoxiao/ssdkeras/project_in_git/MobileNetv2_SSDlite/losses/keras_ssd_loss.py:170: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# n_negative_keep Tensor("loss/ssd_predictions_loss/Minimum:0", shape=(), dtype=int32)
# Tensor("loss/ssd_predictions_loss/Mul_5:0", shape=(?,), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_input (InputLayer)          (1, 1, 300, 300, 3)  0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (1, 1, 302, 301, 3)  0           img_input[0][0]
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (1, 1, 150, 150, 32) 864         time_distributed_1[0][0]
# __________________________________________________________________________________________________
# bbn_stage1_block1_bn (BatchNorm (1, 1, 150, 150, 32) 128         time_distributed_2[0][0]
# __________________________________________________________________________________________________
# bbn_stage1_block1_relu (ReLU)   (1, 1, 150, 150, 32) 0           bbn_stage1_block1_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (1, 1, 150, 150, 32) 288         bbn_stage1_block1_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage1_block2_dw_bn (BatchN (1, 1, 150, 150, 32) 128         time_distributed_3[0][0]
# __________________________________________________________________________________________________
# bbn_stage1_block2_dw_relu (ReLU (1, 1, 150, 150, 32) 0           bbn_stage1_block2_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (1, 1, 150, 150, 16) 512         bbn_stage1_block2_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage1_block2_project_bn (B (1, 1, 150, 150, 16) 64          time_distributed_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (1, 1, 150, 150, 96) 1536        bbn_stage1_block2_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage2_block1_expand_bn (Ba (1, 1, 150, 150, 96) 384         time_distributed_5[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block1_expand_relu ( (1, 1, 150, 150, 96) 0           bbn_stage2_block1_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (1, 1, 152, 151, 96) 0           bbn_stage2_block1_expand_relu[0][
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (1, 1, 75, 75, 96)   864         time_distributed_6[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block1_dw_bn (BatchN (1, 1, 75, 75, 96)   384         time_distributed_7[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block1_dw_relu (ReLU (1, 1, 75, 75, 96)   0           bbn_stage2_block1_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (1, 1, 75, 75, 24)   2304        bbn_stage2_block1_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block1_project_bn (B (1, 1, 75, 75, 24)   96          time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (1, 1, 75, 75, 144)  3456        bbn_stage2_block1_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage2_block2_expand_bn (Ba (1, 1, 75, 75, 144)  576         time_distributed_9[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block2_expand_relu ( (1, 1, 75, 75, 144)  0           bbn_stage2_block2_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (1, 1, 75, 75, 144)  1296        bbn_stage2_block2_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage2_block2_dw_bn (BatchN (1, 1, 75, 75, 144)  576         time_distributed_10[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block2_dw_relu (ReLU (1, 1, 75, 75, 144)  0           bbn_stage2_block2_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (1, 1, 75, 75, 24)   3456        bbn_stage2_block2_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block2_project_bn (B (1, 1, 75, 75, 24)   96          time_distributed_11[0][0]
# __________________________________________________________________________________________________
# bbn_stage2_block2_add (Add)     (1, 1, 75, 75, 24)   0           bbn_stage2_block1_project_bn[0][0
#                                                                  bbn_stage2_block2_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (1, 1, 75, 75, 144)  3456        bbn_stage2_block2_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block1_expand_bn (Ba (1, 1, 75, 75, 144)  576         time_distributed_12[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block1_expand_relu ( (1, 1, 75, 75, 144)  0           bbn_stage3_block1_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (1, 1, 77, 77, 144)  0           bbn_stage3_block1_expand_relu[0][
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (1, 1, 38, 38, 144)  1296        time_distributed_13[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block1_dw_bn (BatchN (1, 1, 38, 38, 144)  576         time_distributed_14[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block1_dw_relu (ReLU (1, 1, 38, 38, 144)  0           bbn_stage3_block1_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (1, 1, 38, 38, 32)   4608        bbn_stage3_block1_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block1_project_bn (B (1, 1, 38, 38, 32)   128         time_distributed_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (1, 1, 38, 38, 192)  6144        bbn_stage3_block1_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage3_block2_expand_bn (Ba (1, 1, 38, 38, 192)  768         time_distributed_16[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block2_expand_relu ( (1, 1, 38, 38, 192)  0           bbn_stage3_block2_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (1, 1, 38, 38, 192)  1728        bbn_stage3_block2_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage3_block2_dw_bn (BatchN (1, 1, 38, 38, 192)  768         time_distributed_17[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block2_dw_relu (ReLU (1, 1, 38, 38, 192)  0           bbn_stage3_block2_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (1, 1, 38, 38, 32)   6144        bbn_stage3_block2_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block2_project_bn (B (1, 1, 38, 38, 32)   128         time_distributed_18[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block2_add (Add)     (1, 1, 38, 38, 32)   0           bbn_stage3_block1_project_bn[0][0
#                                                                  bbn_stage3_block2_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (1, 1, 38, 38, 192)  6144        bbn_stage3_block2_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block3_expand_bn (Ba (1, 1, 38, 38, 192)  768         time_distributed_19[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block3_expand_relu ( (1, 1, 38, 38, 192)  0           bbn_stage3_block3_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (1, 1, 38, 38, 192)  1728        bbn_stage3_block3_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage3_block3_dw_bn (BatchN (1, 1, 38, 38, 192)  768         time_distributed_20[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block3_dw_relu (ReLU (1, 1, 38, 38, 192)  0           bbn_stage3_block3_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (1, 1, 38, 38, 32)   6144        bbn_stage3_block3_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block3_project_bn (B (1, 1, 38, 38, 32)   128         time_distributed_21[0][0]
# __________________________________________________________________________________________________
# bbn_stage3_block3_add (Add)     (1, 1, 38, 38, 32)   0           bbn_stage3_block2_add[0][0]
#                                                                  bbn_stage3_block3_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (1, 1, 38, 38, 192)  6144        bbn_stage3_block3_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block1_expand_bn (Ba (1, 1, 38, 38, 192)  768         time_distributed_22[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block1_expand_relu ( (1, 1, 38, 38, 192)  0           bbn_stage4_block1_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (1, 1, 40, 39, 192)  0           bbn_stage4_block1_expand_relu[0][
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (1, 1, 19, 19, 192)  1728        time_distributed_23[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block1_dw_bn (BatchN (1, 1, 19, 19, 192)  768         time_distributed_24[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block1_dw_relu (ReLU (1, 1, 19, 19, 192)  0           bbn_stage4_block1_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (1, 1, 19, 19, 64)   12288       bbn_stage4_block1_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block1_project_bn (B (1, 1, 19, 19, 64)   256         time_distributed_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (1, 1, 19, 19, 384)  24576       bbn_stage4_block1_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage4_block2_expand_bn (Ba (1, 1, 19, 19, 384)  1536        time_distributed_26[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block2_expand_relu ( (1, 1, 19, 19, 384)  0           bbn_stage4_block2_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (1, 1, 19, 19, 384)  3456        bbn_stage4_block2_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block2_dw_bn (BatchN (1, 1, 19, 19, 384)  1536        time_distributed_27[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block2_dw_relu (ReLU (1, 1, 19, 19, 384)  0           bbn_stage4_block2_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (1, 1, 19, 19, 64)   24576       bbn_stage4_block2_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block2_project_bn (B (1, 1, 19, 19, 64)   256         time_distributed_28[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block2_add (Add)     (1, 1, 19, 19, 64)   0           bbn_stage4_block1_project_bn[0][0
#                                                                  bbn_stage4_block2_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (1, 1, 19, 19, 384)  24576       bbn_stage4_block2_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block3_expand_bn (Ba (1, 1, 19, 19, 384)  1536        time_distributed_29[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block3_expand_relu ( (1, 1, 19, 19, 384)  0           bbn_stage4_block3_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (1, 1, 19, 19, 384)  3456        bbn_stage4_block3_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block3_dw_bn (BatchN (1, 1, 19, 19, 384)  1536        time_distributed_30[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block3_dw_relu (ReLU (1, 1, 19, 19, 384)  0           bbn_stage4_block3_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (1, 1, 19, 19, 64)   24576       bbn_stage4_block3_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block3_project_bn (B (1, 1, 19, 19, 64)   256         time_distributed_31[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block3_add (Add)     (1, 1, 19, 19, 64)   0           bbn_stage4_block2_add[0][0]
#                                                                  bbn_stage4_block3_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (1, 1, 19, 19, 384)  24576       bbn_stage4_block3_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block4_expand_bn (Ba (1, 1, 19, 19, 384)  1536        time_distributed_32[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block4_expand_relu ( (1, 1, 19, 19, 384)  0           bbn_stage4_block4_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (1, 1, 19, 19, 384)  3456        bbn_stage4_block4_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block4_dw_bn (BatchN (1, 1, 19, 19, 384)  1536        time_distributed_33[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block4_dw_relu (ReLU (1, 1, 19, 19, 384)  0           bbn_stage4_block4_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (1, 1, 19, 19, 64)   24576       bbn_stage4_block4_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block4_project_bn (B (1, 1, 19, 19, 64)   256         time_distributed_34[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block4_add (Add)     (1, 1, 19, 19, 64)   0           bbn_stage4_block3_add[0][0]
#                                                                  bbn_stage4_block4_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (1, 1, 19, 19, 384)  24576       bbn_stage4_block4_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block5_expand_bn (Ba (1, 1, 19, 19, 384)  1536        time_distributed_35[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block5_expand_relu ( (1, 1, 19, 19, 384)  0           bbn_stage4_block5_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (1, 1, 19, 19, 384)  3456        bbn_stage4_block5_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block5_dw_bn (BatchN (1, 1, 19, 19, 384)  1536        time_distributed_36[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block5_dw_relu (ReLU (1, 1, 19, 19, 384)  0           bbn_stage4_block5_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (1, 1, 19, 19, 96)   36864       bbn_stage4_block5_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block5_project_bn (B (1, 1, 19, 19, 96)   384         time_distributed_37[0][0]
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (1, 1, 19, 19, 576)  55296       bbn_stage4_block5_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage4_block6_expand_bn (Ba (1, 1, 19, 19, 576)  2304        time_distributed_38[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block6_expand_relu ( (1, 1, 19, 19, 576)  0           bbn_stage4_block6_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (1, 1, 19, 19, 576)  5184        bbn_stage4_block6_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block6_dw_bn (BatchN (1, 1, 19, 19, 576)  2304        time_distributed_39[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block6_dw_relu (ReLU (1, 1, 19, 19, 576)  0           bbn_stage4_block6_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (1, 1, 19, 19, 96)   55296       bbn_stage4_block6_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block6_project_bn (B (1, 1, 19, 19, 96)   384         time_distributed_40[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block6_add (Add)     (1, 1, 19, 19, 96)   0           bbn_stage4_block5_project_bn[0][0
#                                                                  bbn_stage4_block6_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (1, 1, 19, 19, 576)  55296       bbn_stage4_block6_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block7_expand_bn (Ba (1, 1, 19, 19, 576)  2304        time_distributed_41[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block7_expand_relu ( (1, 1, 19, 19, 576)  0           bbn_stage4_block7_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (1, 1, 19, 19, 576)  5184        bbn_stage4_block7_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage4_block7_dw_bn (BatchN (1, 1, 19, 19, 576)  2304        time_distributed_42[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block7_dw_relu (ReLU (1, 1, 19, 19, 576)  0           bbn_stage4_block7_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (1, 1, 19, 19, 96)   55296       bbn_stage4_block7_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block7_project_bn (B (1, 1, 19, 19, 96)   384         time_distributed_43[0][0]
# __________________________________________________________________________________________________
# bbn_stage4_block7_add (Add)     (1, 1, 19, 19, 96)   0           bbn_stage4_block6_add[0][0]
#                                                                  bbn_stage4_block7_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (1, 1, 19, 19, 576)  55296       bbn_stage4_block7_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block1_expand_bn (Ba (1, 1, 19, 19, 576)  2304        time_distributed_44[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block1_expand_relu ( (1, 1, 19, 19, 576)  0           bbn_stage5_block1_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (1, 1, 21, 21, 576)  0           bbn_stage5_block1_expand_relu[0][
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (1, 1, 10, 10, 576)  5184        time_distributed_45[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block1_dw_bn (BatchN (1, 1, 10, 10, 576)  2304        time_distributed_46[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block1_dw_relu (ReLU (1, 1, 10, 10, 576)  0           bbn_stage5_block1_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (1, 1, 10, 10, 160)  92160       bbn_stage5_block1_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block1_project_bn (B (1, 1, 10, 10, 160)  640         time_distributed_47[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (1, 1, 10, 10, 960)  153600      bbn_stage5_block1_project_bn[0][0
# __________________________________________________________________________________________________
# bbn_stage5_block2_expand_bn (Ba (1, 1, 10, 10, 960)  3840        time_distributed_48[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block2_expand_relu ( (1, 1, 10, 10, 960)  0           bbn_stage5_block2_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (1, 1, 10, 10, 960)  8640        bbn_stage5_block2_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage5_block2_dw_bn (BatchN (1, 1, 10, 10, 960)  3840        time_distributed_49[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block2_dw_relu (ReLU (1, 1, 10, 10, 960)  0           bbn_stage5_block2_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (1, 1, 10, 10, 160)  153600      bbn_stage5_block2_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block2_project_bn (B (1, 1, 10, 10, 160)  640         time_distributed_50[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block2_add (Add)     (1, 1, 10, 10, 160)  0           bbn_stage5_block1_project_bn[0][0
#                                                                  bbn_stage5_block2_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (1, 1, 10, 10, 960)  153600      bbn_stage5_block2_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block3_expand_bn (Ba (1, 1, 10, 10, 960)  3840        time_distributed_51[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block3_expand_relu ( (1, 1, 10, 10, 960)  0           bbn_stage5_block3_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (1, 1, 10, 10, 960)  8640        bbn_stage5_block3_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage5_block3_dw_bn (BatchN (1, 1, 10, 10, 960)  3840        time_distributed_52[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block3_dw_relu (ReLU (1, 1, 10, 10, 960)  0           bbn_stage5_block3_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (1, 1, 10, 10, 160)  153600      bbn_stage5_block3_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block3_project_bn (B (1, 1, 10, 10, 160)  640         time_distributed_53[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block3_add (Add)     (1, 1, 10, 10, 160)  0           bbn_stage5_block2_add[0][0]
#                                                                  bbn_stage5_block3_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (1, 1, 10, 10, 960)  153600      bbn_stage5_block3_add[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block4_expand_bn (Ba (1, 1, 10, 10, 960)  3840        time_distributed_54[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block4_expand_relu ( (1, 1, 10, 10, 960)  0           bbn_stage5_block4_expand_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (1, 1, 10, 10, 960)  8640        bbn_stage5_block4_expand_relu[0][
# __________________________________________________________________________________________________
# bbn_stage5_block4_dw_bn (BatchN (1, 1, 10, 10, 960)  3840        time_distributed_55[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block4_dw_relu (ReLU (1, 1, 10, 10, 960)  0           bbn_stage5_block4_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (1, 1, 10, 10, 320)  307200      bbn_stage5_block4_dw_relu[0][0]
# __________________________________________________________________________________________________
# bbn_stage5_block4_project_bn (B (1, 1, 10, 10, 320)  1280        time_distributed_56[0][0]
# __________________________________________________________________________________________________
# bottleneck_lst_m2d_1 (Bottlenec (1, 1, 10, 10, 80)   64240       bbn_stage5_block4_project_bn[0][0
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (1, 1, 10, 10, 1280) 102400      bottleneck_lst_m2d_1[0][0]
# __________________________________________________________________________________________________
# ssd_2_conv_bn (BatchNormalizati (1, 1, 10, 10, 1280) 5120        time_distributed_57[0][0]
# __________________________________________________________________________________________________
# ssd_2_conv_relu (ReLU)          (1, 1, 10, 10, 1280) 0           ssd_2_conv_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (1, 1, 10, 10, 256)  327680      ssd_2_conv_relu[0][0]
# __________________________________________________________________________________________________
# ssd_3_conv_bn (BatchNormalizati (1, 1, 10, 10, 256)  1024        time_distributed_58[0][0]
# __________________________________________________________________________________________________
# ssd_3_conv_relu (ReLU)          (1, 1, 10, 10, 256)  0           ssd_3_conv_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (1, 1, 12, 11, 256)  0           ssd_3_conv_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (1, 1, 5, 5, 256)    2304        time_distributed_59[0][0]
# __________________________________________________________________________________________________
# ssd_3_dw_bn (BatchNormalization (1, 1, 5, 5, 256)    1024        time_distributed_60[0][0]
# __________________________________________________________________________________________________
# ssd_3_dw_relu (ReLU)            (1, 1, 5, 5, 256)    0           ssd_3_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (1, 1, 5, 5, 512)    131072      ssd_3_dw_relu[0][0]
# __________________________________________________________________________________________________
# ssd_3_conv2_bn (BatchNormalizat (1, 1, 5, 5, 512)    2048        time_distributed_61[0][0]
# __________________________________________________________________________________________________
# ssd_3_conv2_relu (ReLU)         (1, 1, 5, 5, 512)    0           ssd_3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (1, 1, 5, 5, 128)    65536       ssd_3_conv2_relu[0][0]
# __________________________________________________________________________________________________
# ssd_4_conv_bn (BatchNormalizati (1, 1, 5, 5, 128)    512         time_distributed_62[0][0]
# __________________________________________________________________________________________________
# ssd_4_conv_relu (ReLU)          (1, 1, 5, 5, 128)    0           ssd_4_conv_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_63 (TimeDistri (1, 1, 7, 7, 128)    0           ssd_4_conv_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_64 (TimeDistri (1, 1, 3, 3, 128)    1152        time_distributed_63[0][0]
# __________________________________________________________________________________________________
# ssd_4_dw_bn (BatchNormalization (1, 1, 3, 3, 128)    512         time_distributed_64[0][0]
# __________________________________________________________________________________________________
# ssd_4_dw_relu (ReLU)            (1, 1, 3, 3, 128)    0           ssd_4_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (1, 1, 3, 3, 256)    32768       ssd_4_dw_relu[0][0]
# __________________________________________________________________________________________________
# ssd_4_conv2_bn (BatchNormalizat (1, 1, 3, 3, 256)    1024        time_distributed_65[0][0]
# __________________________________________________________________________________________________
# ssd_4_conv2_relu (ReLU)         (1, 1, 3, 3, 256)    0           ssd_4_conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (1, 1, 3, 3, 128)    32768       ssd_4_conv2_relu[0][0]
# __________________________________________________________________________________________________
# ssd_5_conv_bn (BatchNormalizati (1, 1, 3, 3, 128)    512         time_distributed_66[0][0]
# __________________________________________________________________________________________________
# ssd_5_conv_relu (ReLU)          (1, 1, 3, 3, 128)    0           ssd_5_conv_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (1, 1, 5, 5, 128)    0           ssd_5_conv_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (1, 1, 2, 2, 128)    1152        time_distributed_67[0][0]
# __________________________________________________________________________________________________
# ssd_5_dw_bn (BatchNormalization (1, 1, 2, 2, 128)    512         time_distributed_68[0][0]
# __________________________________________________________________________________________________
# ssd_5_dw_relu (ReLU)            (1, 1, 2, 2, 128)    0           ssd_5_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (1, 1, 2, 2, 256)    32768       ssd_5_dw_relu[0][0]
# __________________________________________________________________________________________________
# ssd_5_conv2_bn (BatchNormalizat (1, 1, 2, 2, 256)    1024        time_distributed_69[0][0]
# __________________________________________________________________________________________________
# ssd_5_conv2_relu (ReLU)         (1, 1, 2, 2, 256)    0           ssd_5_conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (1, 1, 10, 10, 1280) 11520       ssd_2_conv_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (1, 1, 5, 5, 512)    4608        ssd_3_conv2_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (1, 1, 3, 3, 256)    2304        ssd_4_conv2_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (1, 1, 2, 2, 256)    2304        ssd_5_conv2_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (1, 1, 10, 10, 1280) 11520       ssd_2_conv_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_80 (TimeDistri (1, 1, 5, 5, 512)    4608        ssd_3_conv2_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_82 (TimeDistri (1, 1, 3, 3, 256)    2304        ssd_4_conv2_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_84 (TimeDistri (1, 1, 2, 2, 256)    2304        ssd_5_conv2_relu[0][0]
# __________________________________________________________________________________________________
# ssd_cls2_dw_bn (BatchNormalizat (1, 1, 10, 10, 1280) 5120        time_distributed_70[0][0]
# __________________________________________________________________________________________________
# ssd_cls3_dw_bn (BatchNormalizat (1, 1, 5, 5, 512)    2048        time_distributed_72[0][0]
# __________________________________________________________________________________________________
# ssd_cls4_dw_bn (BatchNormalizat (1, 1, 3, 3, 256)    1024        time_distributed_74[0][0]
# __________________________________________________________________________________________________
# ssd_cls5_dw_bn (BatchNormalizat (1, 1, 2, 2, 256)    1024        time_distributed_76[0][0]
# __________________________________________________________________________________________________
# ssd_box2_dw_bn (BatchNormalizat (1, 1, 10, 10, 1280) 5120        time_distributed_78[0][0]
# __________________________________________________________________________________________________
# ssd_box3_dw_bn (BatchNormalizat (1, 1, 5, 5, 512)    2048        time_distributed_80[0][0]
# __________________________________________________________________________________________________
# ssd_box4_dw_bn (BatchNormalizat (1, 1, 3, 3, 256)    1024        time_distributed_82[0][0]
# __________________________________________________________________________________________________
# ssd_box5_dw_bn (BatchNormalizat (1, 1, 2, 2, 256)    1024        time_distributed_84[0][0]
# __________________________________________________________________________________________________
# ssd_cls2_dw_relu (ReLU)         (1, 1, 10, 10, 1280) 0           ssd_cls2_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls3_dw_relu (ReLU)         (1, 1, 5, 5, 512)    0           ssd_cls3_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls4_dw_relu (ReLU)         (1, 1, 3, 3, 256)    0           ssd_cls4_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls5_dw_relu (ReLU)         (1, 1, 2, 2, 256)    0           ssd_cls5_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box2_dw_relu (ReLU)         (1, 1, 10, 10, 1280) 0           ssd_box2_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box3_dw_relu (ReLU)         (1, 1, 5, 5, 512)    0           ssd_box3_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box4_dw_relu (ReLU)         (1, 1, 3, 3, 256)    0           ssd_box4_dw_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box5_dw_relu (ReLU)         (1, 1, 2, 2, 256)    0           ssd_box5_dw_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (1, 1, 10, 10, 48)   61440       ssd_cls2_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (1, 1, 5, 5, 48)     24576       ssd_cls3_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (1, 1, 3, 3, 48)     12288       ssd_cls4_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (1, 1, 2, 2, 32)     8192        ssd_cls5_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_79 (TimeDistri (1, 1, 10, 10, 24)   30720       ssd_box2_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_81 (TimeDistri (1, 1, 5, 5, 24)     12288       ssd_box3_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_83 (TimeDistri (1, 1, 3, 3, 24)     6144        ssd_box4_dw_relu[0][0]
# __________________________________________________________________________________________________
# time_distributed_85 (TimeDistri (1, 1, 2, 2, 16)     4096        ssd_box5_dw_relu[0][0]
# __________________________________________________________________________________________________
# ssd_cls2conv2_bn (BatchNormaliz (1, 1, 10, 10, 48)   192         time_distributed_71[0][0]
# __________________________________________________________________________________________________
# ssd_cls3conv2_bn (BatchNormaliz (1, 1, 5, 5, 48)     192         time_distributed_73[0][0]
# __________________________________________________________________________________________________
# ssd_cls4conv2_bn (BatchNormaliz (1, 1, 3, 3, 48)     192         time_distributed_75[0][0]
# __________________________________________________________________________________________________
# ssd_cls5conv2_bn (BatchNormaliz (1, 1, 2, 2, 32)     128         time_distributed_77[0][0]
# __________________________________________________________________________________________________
# ssd_box2conv2_bn (BatchNormaliz (1, 1, 10, 10, 24)   96          time_distributed_79[0][0]
# __________________________________________________________________________________________________
# ssd_box3conv2_bn (BatchNormaliz (1, 1, 5, 5, 24)     96          time_distributed_81[0][0]
# __________________________________________________________________________________________________
# ssd_box4conv2_bn (BatchNormaliz (1, 1, 3, 3, 24)     96          time_distributed_83[0][0]
# __________________________________________________________________________________________________
# ssd_box5conv2_bn (BatchNormaliz (1, 1, 2, 2, 16)     64          time_distributed_85[0][0]
# __________________________________________________________________________________________________
# ssd_cls2_reshape (Reshape)      (1, 600, 8)          0           ssd_cls2conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls3_reshape (Reshape)      (1, 150, 8)          0           ssd_cls3conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls4_reshape (Reshape)      (1, 54, 8)           0           ssd_cls4conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls5_reshape (Reshape)      (1, 16, 8)           0           ssd_cls5conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_86 (TimeDistri (1, 1, 10, 10, 6, 8) 0           ssd_box2conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_87 (TimeDistri (1, 1, 5, 5, 6, 8)   0           ssd_box3conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_88 (TimeDistri (1, 1, 3, 3, 6, 8)   0           ssd_box4conv2_bn[0][0]
# __________________________________________________________________________________________________
# time_distributed_89 (TimeDistri (1, 1, 2, 2, 4, 8)   0           ssd_box5conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_cls (Concatenate)           (1, 820, 8)          0           ssd_cls2_reshape[0][0]
#                                                                  ssd_cls3_reshape[0][0]
#                                                                  ssd_cls4_reshape[0][0]
#                                                                  ssd_cls5_reshape[0][0]
# __________________________________________________________________________________________________
# ssd_box2_reshape (Reshape)      (1, 600, 4)          0           ssd_box2conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box3_reshape (Reshape)      (1, 150, 4)          0           ssd_box3conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box4_reshape (Reshape)      (1, 54, 4)           0           ssd_box4conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_box5_reshape (Reshape)      (1, 16, 4)           0           ssd_box5conv2_bn[0][0]
# __________________________________________________________________________________________________
# ssd_priorbox2_reshape (Reshape) (1, 600, 8)          0           time_distributed_86[0][0]
# __________________________________________________________________________________________________
# ssd_priorbox3_reshape (Reshape) (1, 150, 8)          0           time_distributed_87[0][0]
# __________________________________________________________________________________________________
# ssd_priorbox4_reshape (Reshape) (1, 54, 8)           0           time_distributed_88[0][0]
# __________________________________________________________________________________________________
# ssd_priorbox5_reshape (Reshape) (1, 16, 8)           0           time_distributed_89[0][0]
# __________________________________________________________________________________________________
# ssd_mbox_conf_softmax (Activati (1, 820, 8)          0           ssd_cls[0][0]
# __________________________________________________________________________________________________
# ssd_box (Concatenate)           (1, 820, 4)          0           ssd_box2_reshape[0][0]
#                                                                  ssd_box3_reshape[0][0]
#                                                                  ssd_box4_reshape[0][0]
#                                                                  ssd_box5_reshape[0][0]
# __________________________________________________________________________________________________
# ssd_priorbox (Concatenate)      (1, 820, 8)          0           ssd_priorbox2_reshape[0][0]
#                                                                  ssd_priorbox3_reshape[0][0]
#                                                                  ssd_priorbox4_reshape[0][0]
#                                                                  ssd_priorbox5_reshape[0][0]
# __________________________________________________________________________________________________
# ssd_predictions (Concatenate)   (1, 820, 20)         0           ssd_mbox_conf_softmax[0][0]
#                                                                  ssd_box[0][0]
#                                                                  ssd_priorbox[0][0]
# ==================================================================================================
# Total params: 2,871,120
# Trainable params: 2,823,168
# Non-trainable params: 47,952
# __________________________________________________________________________________________________
# None

# %%
# 1: Instantiate two `DataGenerator` objects: One for training, one for validation.

# Optional: If you have enough memory, consider loading the images into memory for the reasons explained above.

train_dataset = DataGenerator()#(load_images_into_memory=False, hdf5_dataset_path=None)
val_dataset = DataGenerator()#(load_images_into_memory=False, hdf5_dataset_path=None)

# 2: Parse the image and label lists for the training and validation datasets. This can take a while.

# TODO: Set the paths to the datasets here.
Worldwide
# The directories that contain the images.
VOC_2007_images_dir = './data_index/data/pic/'

# The directories that contain the annotations.
VOC_2007_annotations_dir = './data_index/data/label/'
#train and val_for_lstm are modified to make the size of datasets fit the batch size of lstm model
#VOC_2007_trainval_image_set_filename = './data_index/data/train_fileNames_with_sequenceNum_forLstm.txt' # used with lstm generator
VOC_2007_trainval_image_set_filename = './data_index/data/train_seqs_list_forBottleneckLSTM.txt' # used with the origin lstm generator
#VOC_2007_test_image_set_filename     = './data_index/data/val_seqs_list_forBottleneckLSTM.txt'
VOC_2007_test_image_set_filename     = './data_index/data/val_for_lstm.txt'
# The XML parser needs to now what object class names to look for and in which order to map them to integers.
#classes = ['background','human','bicycle','truck','car','bus','motorbike','escooter']
classes = ['background','human','bicycle','truck','car','bus','escooter','motorbike']


train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                        image_set_filenames=[VOC_2007_trainval_image_set_filename],
                        annotations_dirs=[VOC_2007_annotations_dir],
                        classes=classes,
                        include_classes='all',
                        exclude_truncated=False,
                        exclude_difficult=False,
                        ret=False)

val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      image_set_filenames=[VOC_2007_test_image_set_filename],
                      annotations_dirs=[VOC_2007_annotations_dir],
                      classes=classes,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=False,#used to be True
                      ret=False)

# Optional: Convert the dataset into an HDF5 dataset. This will require more disk space, but will
# speed up the training. Doing this is not relevant in case you activated the `load_images_into_memory`
# option in the constructor, because in that cas the images are in memory already anyway. If you don't
# want to create HDF5 datasets, comment out the subsequent two function calls.

train_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_trainval.h5',
                                  resize=False,
                                  variable_image_size=True,
                                  verbose=True)

val_dataset.create_hdf5_dataset(file_path='dataset_pascal_voc_07_test.h5',
                                resize=False,
                                variable_image_size=True,
                                verbose=True)
# Out:
# Processing image set 'train_seqs_list_forBottleneckLSTM.txt': 100%|██████████| 10790/10790 [00:12<00:00, 843.27it/s]
# Processing image set 'val_for_lstm.txt': 100%|██████████| 500/500 [00:00<00:00, 1168.21it/s]
# Creating HDF5 dataset: 100%|██████████| 10790/10790 [00:24<00:00, 437.92it/s]
# Creating HDF5 dataset: 100%|██████████| 320/320 [00:00<00:00, 514.26it/s]

# %%
# learning rate schedule
def lr_schedule(epoch):
    if epoch < 200:
        return 0.003
    elif epoch < 500:
        return 0.0001
    else:
        return 0.00001


# set trainable layers
def set_trainable(layer_regex, keras_model=None, indent=0, verbose=1):
    # In multi-GPU training, we wrap the model. Get layers
    # of the inner model because they have the weights.
    layers = keras_model.inner_model.layers if hasattr(keras_model, "inner_model") \
        else keras_model.layers

    for layer in layers:
        # Is the layer a model?
        if layer.__class__.__name__ == 'Model':
            print("In model: ", layer.name)
            set_trainable(
                layer_regex, keras_model=layer)
            continue

        if not layer.weights:
            continue
        # Is it trainable?
        trainable = bool(re.fullmatch(layer_regex, layer.name))
        # Update layer. If layer is a container, update inner layer.
        if layer.__class__.__name__ == 'TimeDistributed':
            layer.layer.trainable = trainable
        else:
            layer.trainable = trainable
        # Print trainable layer names
        if trainable and verbose > 0:
            print("{}{:20}   ({})".format(" " * indent, layer.name, layer.__class__.__name__))

# %%
# 3: Set the batch size.

#batch_size = 8 # Change the batch size if you like, or if you run into GPU memory issues.

# 4: Set the train_datasetimage transformations for pre-processing and data augmentation options.

# For the training generator:
# no extra 
ssd_data_augmentation = SSDDataAugmentation(img_height=img_height,
                                            img_width=img_width)



# set trainable layers
def set_trainable(layer_regex, keras_model=None, indent=0, verbose=1):
    # In multi-GPU training, we wrap the model. Get layers
    # of the inner model because they have the weights.
    layers = keras_model.inner_model.layers if hasattr(keras_model, "inner_model") \
        else keras_model.layers

    for layer in layers:
        # Is the layer a model?
        if layer.__class__.__name__ == 'Model':
            print("In model: ", layer.name)
            set_trainable(
                layer_regex, keras_model=layer)
            continue

        if not layer.weights:
            continue
        # Is it trainable?
        trainable = bool(re.fullmatch(layer_regex, layer.name))
        # Update layer. If layer is a container, update inner layer.
        if layer.__class__.__name__ == 'TimeDistributed':
            layer.layer.trainable = trainable
        else:
            layer.trainable = trainable
        # Print trainable layer names
        if trainable and verbose > 0:
            print("{}{:20}   ({})".format(" " * indent, layer.name, layer.__class__.__name__))

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=img_height, width=img_width)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.
#用getlayer来获取输出层的尺寸
# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
predictor_sizes = [model.layers[-29].output_shape[2:4],
                   model.layers[-28].output_shape[2:4],
                   model.layers[-27].output_shape[2:4],
                   model.layers[-26].output_shape[2:4]]
'''
predictor_sizes = [model.get_layer('ssd_cls1conv2_bn').output_shape[2:4],
                   model.get_layer('ssd_cls2conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls3conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls4conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls5conv2_bn').output_shape[1:3],
                   model.get_layer('ssd_cls6conv2_bn').output_shape[1:3]]
'''
#encoder把ground truth labels
ssd_input_encoder = SSDInputEncoder(img_height=img_height,
                                    img_width=img_width,
                                    n_classes=n_classes,
                                    predictor_sizes=predictor_sizes,
                                    scales=scales,
                                    aspect_ratios_per_layer=aspect_ratios,
                                    two_boxes_for_ar1=two_boxes_for_ar1,
                                    steps=steps,
                                    offsets=offsets,
                                    clip_boxes=clip_boxes,
                                    variances=variances,
                                    matching_type='multi',
                                    pos_iou_threshold=0.5,
                                    neg_iou_limit=0.5,
                                    normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size, ###注 意sequence size and batch size
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                      resize],# used to be augumentation
                                         label_encoder=ssd_input_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=True,
                                         seq_size=sequence_size)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=ssd_input_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=True,
                                     seq_size=sequence_size)

# Get the number of samples in the training and validations datasets.
#train_dataset_size = train_dataset.get_dataset_size()
#val_dataset_size   = val_dataset.get_dataset_size()

#print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
#print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))

# %%
# Define model callbacks.

# TODO: Set the filepath under which you want to save the model.
model_checkpoint = ModelCheckpoint(filepath='./Log_statefulLSTM/MobileNetv2_ssdLite_bottleNeckLSTM_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5',
                                   monitor='loss',#used to be val_loss
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=True,
                                   mode='auto',
                                   period=1)
#model_checkpoint.best = 

csv_logger = CSVLogger(filename='MobileNetv2_ssdLite_training_log.csv',
                       separator=',',
                       append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]

# %%
#print(next(train_generator))

# %%
initial_epoch   = 0
final_epoch     = 120
steps_per_epoch =10790#10740#1079#518#1035#6000
val_dataset_size = 32#82
val_steps=50
for i in range(final_epoch):
    print("This is Epoch", i+1, '/', final_epoch)
    history = model.fit_generator(generator=train_generator,
                                  steps_per_epoch=steps_per_epoch,
                                  epochs=1,
                                  callbacks=callbacks,
                                  validation_data=val_generator,
                                  validation_steps=ceil(val_steps))#ceil(val_dataset_size/batch_size))
    model.reset_states()
# Out:
# This is Epoch 1 / 120
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/xiaoxiao/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 10790/10790 [==============================] - 2490s 231ms/step - loss: 5.5801 - val_loss: 9.8877
#
# Epoch 00001: loss improved from inf to 5.58010, saving model to ./Log_statefulLSTM/MobileNetv2_ssdLite_bottleNeckLSTM_epoch-01_loss-5.5801_val_loss-9.8877.h5
# This is Epoch 2 / 120
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 10790/10790 [==============================] - 2446s 227ms/step - loss: 5.2703 - val_loss: 31.7528
#
# Epoch 00001: loss improved from 5.58010 to 5.27031, saving model to ./Log_statefulLSTM/MobileNetv2_ssdLite_bottleNeckLSTM_epoch-01_loss-5.2703_val_loss-31.7528.h5
# This is Epoch 3 / 120
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 10790/10790 [==============================] - 2496s 231ms/step - loss: 5.3944 - val_loss: 23.6544
#
# Epoch 00001: loss did not improve from 5.27031
# This is Epoch 4 / 120
# Epoch 1/1
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
#  8754/10790 [=======================>......] - ETA: 7:47 - loss: 5.6249
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0c8432c12d57> in <module>
#      11                                   callbacks=callbacks,
#      12                                   validation_data=val_generator,
# ---> 13                                   validation_steps=ceil(val_steps))#ceil(val_dataset_size/batch_size))
#      14     model.reset_states()
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/anaconda3/envs/tf13/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
predict_generator = val_dataset.generate(batch_size=2,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'filenames',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# 2: Generate samples.

batch_images, batch_filenames, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))

# %%
y_pred = model.predict(batch_images)

# %%
# 4: Decode the raw predictions in `y_pred`.

y_pred_decoded = decode_detections(y_pred,
                                   confidence_thresh=0.5,
                                   iou_threshold=0.4,
                                   top_k=200,
                                   normalize_coords=normalize_coords,
                                   img_height=img_height,
                                   img_width=img_width)

# %%
# 5: Convert the predictions for the original image.

y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)

np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# %%
# 5: Draw the predicted boxes onto the image

# Set the colors for the bounding boxes
colors = plt.cm.hsv(np.linspace(0, 1, n_classes+1)).tolist()
classes = ['background','human','bicycle','truck','car','bus']

plt.figure(figsize=(20,12))
plt.imshow(batch_original_images[i])

current_axis = plt.gca()

for box in batch_original_labels[i]:
    xmin = box[1]
    ymin = box[2]
    xmax = box[3]
    ymax = box[4]
    label = '{}'.format(classes[int(box[0])])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color='green', fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':'green', 'alpha':1.0})

for box in y_pred_decoded_inv[i]:
    xmin = box[2]
    ymin = box[3]
    xmax = box[4]
    ymax = box[5]
    color = colors[int(box[0])]
    label = '{}: {:.2f}'.format(classes[int(box[0])], box[1])
    current_axis.add_patch(plt.Rectangle((xmin, ymin), xmax-xmin, ymax-ymin, color=color, fill=False, linewidth=2))  
    current_axis.text(xmin, ymin, label, size='x-large', color='white', bbox={'facecolor':color, 'alpha':1.0})
